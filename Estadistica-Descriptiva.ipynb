# %%
import pandas as pd

# %%
df = pd.read_csv('spotify_songs.csv')
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
song_name = df['track_name'].unique()
track_artist = df['track_artist'].unique()
album_name = df['track_album_name'].unique()
playlist_name = df['playlist_name'].unique()
playlist_genre = df['playlist_genre'].unique()
playlist_subgenre = df['playlist_subgenre'].unique()

# %%
df.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %%
# Group by 'Entity' and calculate mean
artist_popularity = df.groupby('track_artist')['track_popularity'].mean()
artist_popularity = pd.DataFrame(artist_popularity)

# Calculate other statistics like sum, median, etc.
subgenre_dance = df.groupby('playlist_subgenre')['danceability'].sum()
subgenre_dance = pd.DataFrame(subgenre_dance)

# %%
artist_popularity.sort_values('track_popularity',ascending=False)
# Out:
#                   track_popularity
# track_artist
# Trevor Daniel            97.000000
# Y2K                      91.000000
# Don Toliver              90.714286
# Roddy Ricch              88.210526
# DaBaby                   87.857143
# ...                            ...
# Jeff Retro                0.000000
# Baby Doll                 0.000000
# Wreckshop Family          0.000000
# Bacanos                   0.000000
# Joe Bataan                0.000000
#
# [10692 rows x 1 columns]

# %%
genre_dance
# Out:
#                            danceability
# playlist_subgenre
# album rock                     559.1460
# big room                       747.1780
# classic rock                   706.8330
# dance pop                      851.1660
# electro house                 1060.1600
# electropop                     899.1615
# gangster rap                  1055.6290
# hard rock                      724.8040
# hip hop                        951.3480
# hip pop                        848.3320
# indie poptimism               1052.6850
# latin hip hop                 1197.5120
# latin pop                      865.8720
# neo soul                      1055.8900
# new jack swing                 819.5720
# permanent wave                 586.4500
# pop edm                        982.6270
# post-teen pop                  717.6220
# progressive electro house     1168.4470
# reggaeton                      722.1450
# southern hip hop              1197.0900
# trap                           923.5880
# ...
